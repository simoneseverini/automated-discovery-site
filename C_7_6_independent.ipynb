), (2, 5, 6, 0, 5, 2), (0, 5, 0, 5, 6, 1), (5, 0, 4, 6, 3, 0), (0, 5, 0, 3, 6, 2), (1, 3, 4, 2, 5, 6), (4, 1, 2, 3, 3, 3), (0, 5, 0, 4, 2, 0), (5, 2, 4, 1, 3, 6), (1, 6, 2, 6, 1, 0), (5, 6, 6, 6, 4, 5), (4, 5, 3, 1, 6, 4), (3, 0, 4, 1, 4, 4), (6, 3, 6, 2, 4, 2), (0, 1, 5, 0, 5, 0), (0, 4, 1, 6, 4, 5), (1, 3, 5, 0, 0, 0), (5, 6, 6, 1, 4, 4), (3, 4, 1, 5, 2, 4), (0, 5, 1, 2, 5, 5), (6, 0, 1, 5, 6, 6), (4, 4, 5, 2, 6, 3), (2, 4, 1, 6, 1, 6), (1, 4, 3, 1, 0, 0), (2, 2, 0, 2, 5, 4), (0, 6, 5, 0, 6, 5), (6, 1, 1, 5, 3, 2), (2, 5, 4, 3, 3, 3), (6, 6, 3, 4, 4, 0), (6, 4, 4, 2, 1, 4), (3, 3, 3, 5, 6, 5), (0, 6, 5, 3, 2, 5), (2, 1, 3, 0, 4, 0), (6, 1, 6, 5, 6, 5), (3, 0, 4, 3, 5, 3), (0, 3, 1, 1, 1, 6), (1, 1, 5, 0, 3, 1), (5, 2, 2, 6, 3, 6)]}]

# %% [markdown]
# ### Code

# %%
# EVOLVE-BLOCK-START
import time
import random

def find_independent_set_c7_6(time_limit_seconds: float, starting_set: list[tuple]) -> list[tuple]:
    start_time = time.time()

    # Helper function to check if two vertices conflict
    # Assumes u and v are distinct vertices.
    def _are_conflicting(u: tuple, v: tuple) -> bool:
        for i in range(6):
            diff = (u[i] - v[i]) % 7
            if diff not in {0, 1, 6}:
                return False  # Independent in this dimension, so u and v are independent overall
        return True  # All dimensions are 'conflicting', so u and v conflict

    # Helper function to generate a random vertex
    def _generate_random_vertex() -> tuple:
        return tuple(random.randint(0, 6) for _ in range(6))

    # Step 1: Ensure the starting_set is valid.
    # Rebuild the set greedily to ensure all its members are mutually independent.
    # This process has a time complexity of O(N^2) for N elements in starting_set,
    # which is acceptable for typical starting_set sizes within a time limit.
    current_set = set()
    for candidate_from_start in starting_set:
        is_independent_from_current = True
        for member_in_current in current_set:
            # Check for conflict only if candidate_from_start is distinct from member_in_current
            if candidate_from_start != member_in_current and _are_conflicting(candidate_from_start, member_in_current):
                is_independent_from_current = False
                break
        if is_independent_from_current:
            current_set.add(candidate_from_start)

    # Step 2: Greedily add new random vertices until time limit
    # The total number of possible vertices is 7^6 = 117,649.
    # Random selection allows exploring the space without storing all vertices explicitly.
    while time.time() - start_time < time_limit_seconds:
        candidate_new = _generate_random_vertex()

        # Check if candidate is already in the set; if so, skip to avoid redundant work
        # and to correctly handle the _are_conflicting assumption of distinct vertices.
        if candidate_new in current_set:
            continue

        is_independent_from_set = True
        for member_in_current in current_set:
            if _are_conflicting(candidate_new, member_in_current):
                is_independent_from_set = False
                break

        if is_independent_from_set:
            current_set.add(candidate_new)

    return list(current_set)
# EVOLVE-BLOCK-END
import time
import math
import matplotlib.pyplot as plt
import io
import base64

def serialize_image(fig):
    """Converts a matplotlib figure to a base64 string."""
    buf = io.BytesIO()
    fig.savefig(buf, format='png', bbox_inches='tight')
    buf.seek(0)
    data = base64.b64encode(buf.getvalue()).decode('utf-8')
    plt.close(fig)
    return data

def visualize_c7_6_projection(indep_set):
    """
    Visualizes the independent set by projecting the 6D points
    onto 2D.
    """
    fig, ax = plt.subplots(figsize=(6, 6))

    if not indep_set:
        ax.text(0.5, 0.5, "Empty Set", ha='center')
        return serialize_image(fig)

    # Extract coordinates (Projecting Dim 0 vs Dim 1)
    xs = [p[0] for p in indep_set]
    ys = [p[1] for p in indep_set]

    # Add jitter
    import random
    xs_j = [x + random.uniform(-0.3, 0.3) for x in xs]
    ys_j = [y + random.uniform(-0.3, 0.3) for y in ys]

    ax.scatter(xs_j, ys_j, alpha=0.6, c='purple', edgecolors='k', s=50)
    ax.set_title(f"Projection of C7^6 Independent Set (Size: {len(indep_set)})")
    ax.set_xlabel("Dimension 0")
    ax.set_ylabel("Dimension 1")
    ax.set_xticks(range(7))
    ax.set_yticks(range(7))
    ax.grid(True, linestyle='--', alpha=0.5)

    return serialize_image(fig)

def _check_independence_c7_6(u, v):
    """
    Returns True if u and v are independent in C7^6.
    Two vertices are connected if for all i, (u_i - v_i)%7 in {0, 1, 6}.
    Independent if there exists at least one i where diff in {2, 3, 4, 5}.
    """
    for i in range(6):
        diff = (u[i] - v[i]) % 7
        if diff in (2, 3, 4, 5):
            return True # Found a separating coordinate
    return False # Connected

def evaluate(data):
    """
    Evaluates the proposed independent set for C7^6.
    """
    time_limit = 60.0
    parent_outputs = data.get('parent_outputs', {})
    starting_set = parent_outputs.get('best_set', [])

    # 1. Run the evolvable code
    try:
        proposed_set = find_independent_set_c7_6(time_limit, starting_set)
    except Exception as e:
        return {'size': -10000}, {'error': str(e)}

    # 2. Validation
    if not isinstance(proposed_set, list):
        return {'size': -10000}, {'error': "Output must be a list"}

    if len(proposed_set) == 0:
        return {'size': 0}, {'best_set': [], 'image': visualize_c7_6_projection([])}

    unique_set = list(set(proposed_set))
    if len(unique_set) != len(proposed_set):
        proposed_set = unique_set

    for i, pt in enumerate(proposed_set):
        if not isinstance(pt, tuple) or len(pt) != 6:
             return {'size': -10000}, {'error': f"Item {i} is not a 6-tuple"}
        for coord in pt:
            if not isinstance(coord, int) or not (0 <= coord <= 6):
                return {'size': -10000}, {'error': f"Item {i} has invalid coordinates"}

    # Independence check
    # For large sets in 6D, this can be slow, but correctness is paramount.
    for i in range(len(proposed_set)):
        for j in range(i + 1, len(proposed_set)):
            u = proposed_set[i]
            v = proposed_set[j]
            if not _check_independence_c7_6(u, v):
                return {'size': -10000}, {'error': f"Conflict found between {u} and {v}"}

    # 3. Score
    score = float(len(proposed_set))

    # 4. Visualization & Output
    image_data = visualize_c7_6_projection(proposed_set)

    return {'size': score}, {'best_set': proposed_set, 'image': image_data}
